# %% [markdown]
# **A* Search**
#
# Implementation with Visualization of (6x10) matrix at each step. Shows how search explores and finds the goal get the path.
#
# **Note:** If you want just the final answer then its at the last cell

# %%
import pandas as pd
import numpy as np
from IPython.display import Markdown, display
import heapdict

# creating dictionary that stores info abour each cell of the cliff walker maze as per the question
maze_dict=dict()

start_position = (6,1)
goal_position = (6,10)
fringe_a_star=heapdict.heapdict() # heap_dictionary that works like a priority queue for implementing A*
path_a_star=[] # returned path for A*

# backtracking_dict dictionary will be later used to back track the path of traversal that actually led to finding goal
backtracking_dict={start_position:[]}

#DeathZone in red as per question
#Shallow region in white as per question
#Deep region in green as per question
def init_cliff_walker(start_pos, goal_pos):
  for i in range(1,7):
    for j in range(1,11):
      if i==6 and (j<=9 and j>=2):
        maze_dict[(i,j)] = [" ","Deathzone","unvisited"]
      elif (i>=3 and i<=5) and ((j<=4 and j>=2) or (j<=8 and j>=6)):
        maze_dict[(i,j)] = [" ","Deep","unvisited"]
      else:
        maze_dict[(i,j)] = [" ","Shallow","unvisited"]
  maze_dict[start_pos][0] = "START"
  maze_dict[goal_pos][0] = "GOAL"

def print_cliff_walker():
  row_lst = []
  for row_num in range(1,7):
    lst=[]
    for col_num in range(1,11):
      if (row_num,col_num) == start_position or (row_num,col_num) == goal_position or ((row_num,col_num) in path_a_star):
        lst.append(str(maze_dict[(row_num,col_num)][0]))
      elif maze_dict[(row_num,col_num)][2] == "unvisited":
        lst.append(5*'_')
      elif maze_dict[(row_num,col_num)][2] == "visited" and maze_dict[(row_num,col_num)][0] != " ":
        lst.append("\u03BF")
      elif maze_dict[(row_num,col_num)][2] == "visited":
        lst.append("\u03BF")
    row_lst.append(lst)
  
  idx_lst=[str(i) for i in range(1,7)]
  col_lst=[str(i) for i in range(1,11)]

  data_arr = np.array(row_lst)
  df = pd.DataFrame(data_arr, index=idx_lst, columns=col_lst)
  df = df.style.apply(style_specific_cell, axis=None)
  return df

def style_specific_cell(x):

    font_typ = 'font-weight: bold; text-align: center;'
    bg_color = ''
    df1 = pd.DataFrame('', index=x.index, columns=x.columns)
    for key in maze_dict.keys():
      df1.iloc[key[0]-1, key[1]-1] = font_typ
      if maze_dict[key][1] == "Deep":
        bg_color = 'background-color: lightgreen;'
      elif maze_dict[key][1] == "Deathzone":
        bg_color = 'background-color: red;'
      elif maze_dict[key][1] == "Shallow":
        bg_color = 'background-color: white;'
      df1.iloc[key[0]-1, key[1]-1] += bg_color

      if key in path_a_star:
        df1.iloc[key[0]-1, key[1]-1] += 'color: blue;'
      else:
        df1.iloc[key[0]-1, key[1]-1] += 'color: black;'
        
    return df1

# we are using Manhattan distancce as heuristic function to select cells closest to GOAL
def get_heuristic(a,b):
  return abs(a[0]-b[0])+abs(a[1]-b[1])

# For A* search, we combine costs of g(n) and heuristic function h(n)
def get_cell_expense(cell_type):
  if cell_type == "Deep":
    return 5
  elif cell_type == "Shallow":
    return 1

# checks for valid neighbors/children to explore as per environment conditions. 
# Here valid means maze boundary condtions to be in 6x10 matrix, not encountering red deathzone and not revisiting already visited node
def get_valid_neighbors(curr_pos):
  neighbors = [(curr_pos[0]-1,curr_pos[1]), (curr_pos[0],curr_pos[1]-1), (curr_pos[0],curr_pos[1]+1), (curr_pos[0]+1,curr_pos[1])]
  valid=[]
  for i in neighbors:
    if(i[0]<7 and i[0]>0) and (i[1]>0 and i[1]<11) and maze_dict[i][2] == "unvisited" and maze_dict[i][1]!="Deathzone":
      valid.append(i)
  return valid

  
init_cliff_walker(start_position, goal_position)
print("Initiating empty maze for A*")
display(print_cliff_walker())


def a_star():

  print("Fringe => "+ str(list(fringe_a_star.items()))) # Printing the fringe in format (location, f(n) costing)
  curr = fringe_a_star.popitem()[0]
  
  # ignores visited positions to avoid redundant operation
  while maze_dict[curr][2] == "visited":
    curr = fringe_a_star.popitem()[0] # popped item is (location, cost)
  
  maze_dict[curr][2] = "visited"
  print("popped "+str(curr)+" and tracked below")
  display(print_cliff_walker())
  if maze_dict[curr][0]=="GOAL":
    path_a_star.append(curr)
    backtracking_dict[tuple()]= [curr]
    return True
  
  #collecting valid neighbors to expand the A* tree
  children = get_valid_neighbors(curr)
  # adding new children/neighbors to fringe (priority queue)
  for child in children:
    h = get_heuristic(child, goal_position)
    g = get_cell_expense(maze_dict[child][1])
    f = g + h
    # A* depends on two functions to decide its next step: f(n) = g(n) + h(n)
    fringe_a_star[child] = f

  #updating backtracking dictionary
  for child in children:
    if child not in backtracking_dict:
      backtracking_dict[child] = [curr]
    # if child in backtracking_dict:
    #   backtracking_dict[child].append(curr)
    # else:
    #   backtracking_dict[child] = [curr]
  
  # continues recursive call till fringe empty or until GOAL not found
  while (fringe_a_star.items())!=[]:  
    result = a_star()
    if result == True:
      return True  
  return False


#adding root/start node to a_star-fringe to start A*
fringe_a_star[start_position] = get_cell_expense(maze_dict[start_position][1]) + get_heuristic(start_position, goal_position) # f(n) = g(n) + h(n)
if a_star():
  print("A* found GOAL")
else:
  print("A* failed to find GOAL")

#using backtracking to get path
temp_key=(6,10)
while backtracking_dict[temp_key] != []:
  ans = backtracking_dict[temp_key][0]
  path_a_star.append(ans)
  temp_key = ans
path_a_star = [path_a_star[x] for x in range( len(path_a_star)-1,-1,-1)] # reversing list to go from START to GOAL
print("A* path backtracked START to GOAL =>"+str(path_a_star))

a_star_path_cost=0 # gives path cost sum
for i in path_a_star:
  a_star_path_cost += get_cell_expense(maze_dict[i][1])
  if i == start_position or i == goal_position:
    maze_dict[i][0]+= "="+str(a_star_path_cost)
  else:
    maze_dict[i][0]=a_star_path_cost  

print("A* Path Cost = "+str(a_star_path_cost))
print()
print("Output of explored areas with output cost at each step higlighted in blue color:")
display(print_cliff_walker())
# Out:
# Initiating empty maze for A*
# <style type="text/css">
# #T_c496e_row0_col0, #T_c496e_row0_col1, #T_c496e_row0_col2, #T_c496e_row0_col3, #T_c496e_row0_col4, #T_c496e_row0_col5, #T_c496e_row0_col6, #T_c496e_row0_col7, #T_c496e_row0_col8, #T_c496e_row0_col9, #T_c496e_row1_col0, #T_c496e_row1_col1, #T_c496e_row1_col2, #T_c496e_row1_col3, #T_c496e_row1_col4, #T_c496e_row1_col5, #T_c496e_row1_col6, #T_c496e_row1_col7, #T_c496e_row1_col8, #T_c496e_row1_col9, #T_c496e_row2_col0, #T_c496e_row2_col4, #T_c496e_row2_col8, #T_c496e_row2_col9, #T_c496e_row3_col0, #T_c496e_row3_col4, #T_c496e_row3_col8, #T_c496e_row3_col9, #T_c496e_row4_col0, #T_c496e_row4_col4, #T_c496e_row4_col8, #T_c496e_row4_col9, #T_c496e_row5_col0, #T_c496e_row5_col9 {
#   font-weight: bold;
#   text-align: center;
#   background-color: white;
#   color: black;
# }
# #T_c496e_row2_col1, #T_c496e_row2_col2, #T_c496e_row2_col3, #T_c496e_row2_col5, #T_c496e_row2_col6, #T_c496e_row2_col7, #T_c496e_row3_col1, #T_c496e_row3_col2, #T_c496e_row3_col3, #T_c496e_row3_col5, #T_c496e_row3_col6, #T_c496e_row3_col7, #T_c496e_row4_col1, #T_c496e_row4_col2, #T_c496e_row4_col3, #T_c496e_row4_col5, #T_c496e_row4_col6, #T_c496e_row4_col7 {
#   font-weight: bold;
#   text-align: center;
#   background-color: lightgreen;
#   color: black;
# }
# #T_c496e_row5_col1, #T_c496e_row5_col2, #T_c496e_row5_col3, #T_c496e_row5_col4, #T_c496e_row5_col5, #T_c496e_row5_col6, #T_c496e_row5_col7, #T_c496e_row5_col8 {
#   font-weight: bold;
#   text-align: center;
#   background-color: red;
#   color: black;
# }
# </style>
# <table id="T_c496e_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >1</th>
#       <th class="col_heading level0 col1" >2</th>
#       <th class="col_heading level0 col2" >3</th>
#       <th class="col_heading level0 col3" >4</th>
#       <th class="col_heading level0 col4" >5</th>
#       <th class="col_heading level0 col5" >6</th>
#       <th class="col_heading level0 col6" >7</th>
#       <th class="col_heading level0 col7" >8</th>
#       <th class="col_heading level0 col8" >9</th>
#       <th class="col_heading level0 col9" >10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c496e_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_c496e_row0_col0" class="data row0 col0" >_____</td>
#       <td id="T_c496e_row0_col1" class="data row0 col1" >_____</td>
#       <td id="T_c496e_row0_col2" class="data row0 col2" >_____</td>
#       <td id="T_c496e_row0_col3" class="data row0 col3" >_____</td>
#       <td id="T_c496e_row0_col4" class="data row0 col4" >_____</td>
#       <td id="T_c496e_row0_col5" class="data row0 col5" >_____</td>
#       <td id="T_c496e_row0_col6" class="data row0 col6" >_____</td>
#       <td id="T_c496e_row0_col7" class="data row0 col7" >_____</td>
#       <td id="T_c496e_row0_col8" class="data row0 col8" >_____</td>
#       <td id="T_c496e_row0_col9" class="data row0 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_c496e_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_c496e_row1_col0" class="data row1 col0" >_____</td>
#       <td id="T_c496e_row1_col1" class="data row1 col1" >_____</td>
#       <td id="T_c496e_row1_col2" class="data row1 col2" >_____</td>
#       <td id="T_c496e_row1_col3" class="data row1 col3" >_____</td>
#       <td id="T_c496e_row1_col4" class="data row1 col4" >_____</td>
#       <td id="T_c496e_row1_col5" class="data row1 col5" >_____</td>
#       <td id="T_c496e_row1_col6" class="data row1 col6" >_____</td>
#       <td id="T_c496e_row1_col7" class="data row1 col7" >_____</td>
#       <td id="T_c496e_row1_col8" class="data row1 col8" >_____</td>
#       <td id="T_c496e_row1_col9" class="data row1 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_c496e_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_c496e_row2_col0" class="data row2 col0" >_____</td>
#       <td id="T_c496e_row2_col1" class="data row2 col1" >_____</td>
#       <td id="T_c496e_row2_col2" class="data row2 col2" >_____</td>
#       <td id="T_c496e_row2_col3" class="data row2 col3" >_____</td>
#       <td id="T_c496e_row2_col4" class="data row2 col4" >_____</td>
#       <td id="T_c496e_row2_col5" class="data row2 col5" >_____</td>
#       <td id="T_c496e_row2_col6" class="data row2 col6" >_____</td>
#       <td id="T_c496e_row2_col7" class="data row2 col7" >_____</td>
#       <td id="T_c496e_row2_col8" class="data row2 col8" >_____</td>
#       <td id="T_c496e_row2_col9" class="data row2 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_c496e_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_c496e_row3_col0" class="data row3 col0" >_____</td>
#       <td id="T_c496e_row3_col1" class="data row3 col1" >_____</td>
#       <td id="T_c496e_row3_col2" class="data row3 col2" >_____</td>
#       <td id="T_c496e_row3_col3" class="data row3 col3" >_____</td>
#       <td id="T_c496e_row3_col4" class="data row3 col4" >_____</td>
#       <td id="T_c496e_row3_col5" class="data row3 col5" >_____</td>
#       <td id="T_c496e_row3_col6" class="data row3 col6" >_____</td>
#       <td id="T_c496e_row3_col7" class="data row3 col7" >_____</td>
#       <td id="T_c496e_row3_col8" class="data row3 col8" >_____</td>
#       <td id="T_c496e_row3_col9" class="data row3 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_c496e_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_c496e_row4_col0" class="data row4 col0" >_____</td>
#       <td id="T_c496e_row4_col1" class="data row4 col1" >_____</td>
#       <td id="T_c496e_row4_col2" class="data row4 col2" >_____</td>
#       <td id="T_c496e_row4_col3" class="data row4 col3" >_____</td>
#       <td id="T_c496e_row4_col4" class="data row4 col4" >_____</td>
#       <td id="T_c496e_row4_col5" class="data row4 col5" >_____</td>
#       <td id="T_c496e_row4_col6" class="data row4 col6" >_____</td>
#       <td id="T_c496e_row4_col7" class="data row4 col7" >_____</td>
#       <td id="T_c496e_row4_col8" class="data row4 col8" >_____</td>
#       <td id="T_c496e_row4_col9" class="data row4 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_c496e_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_c496e_row5_col0" class="data row5 col0" >START</td>
#       <td id="T_c496e_row5_col1" class="data row5 col1" >_____</td>
#       <td id="T_c496e_row5_col2" class="data row5 col2" >_____</td>
#       <td id="T_c496e_row5_col3" class="data row5 col3" >_____</td>
#       <td id="T_c496e_row5_col4" class="data row5 col4" >_____</td>
#       <td id="T_c496e_row5_col5" class="data row5 col5" >_____</td>
#       <td id="T_c496e_row5_col6" class="data row5 col6" >_____</td>
#       <td id="T_c496e_row5_col7" class="data row5 col7" >_____</td>
#       <td id="T_c496e_row5_col8" class="data row5 col8" >_____</td>
#       <td id="T_c496e_row5_col9" class="data row5 col9" >GOAL</td>
#     </tr>
#   </tbody>
# </table>
# Fringe => [((6, 1), 10)]
# popped (6, 1) and tracked below
# <style type="text/css">
# #T_8eb77_row0_col0, #T_8eb77_row0_col1, #T_8eb77_row0_col2, #T_8eb77_row0_col3, #T_8eb77_row0_col4, #T_8eb77_row0_col5, #T_8eb77_row0_col6, #T_8eb77_row0_col7, #T_8eb77_row0_col8, #T_8eb77_row0_col9, #T_8eb77_row1_col0, #T_8eb77_row1_col1, #T_8eb77_row1_col2, #T_8eb77_row1_col3, #T_8eb77_row1_col4, #T_8eb77_row1_col5, #T_8eb77_row1_col6, #T_8eb77_row1_col7, #T_8eb77_row1_col8, #T_8eb77_row1_col9, #T_8eb77_row2_col0, #T_8eb77_row2_col4, #T_8eb77_row2_col8, #T_8eb77_row2_col9, #T_8eb77_row3_col0, #T_8eb77_row3_col4, #T_8eb77_row3_col8, #T_8eb77_row3_col9, #T_8eb77_row4_col0, #T_8eb77_row4_col4, #T_8eb77_row4_col8, #T_8eb77_row4_col9, #T_8eb77_row5_col0, #T_8eb77_row5_col9 {
#   font-weight: bold;
#   text-align: center;
#   background-color: white;
#   color: black;
# }
# #T
_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_cb99f_row1_col0" class="data row1 col0" >ο</td>
#       <td id="T_cb99f_row1_col1" class="data row1 col1" >_____</td>
#       <td id="T_cb99f_row1_col2" class="data row1 col2" >_____</td>
#       <td id="T_cb99f_row1_col3" class="data row1 col3" >_____</td>
#       <td id="T_cb99f_row1_col4" class="data row1 col4" >_____</td>
#       <td id="T_cb99f_row1_col5" class="data row1 col5" >_____</td>
#       <td id="T_cb99f_row1_col6" class="data row1 col6" >_____</td>
#       <td id="T_cb99f_row1_col7" class="data row1 col7" >_____</td>
#       <td id="T_cb99f_row1_col8" class="data row1 col8" >_____</td>
#       <td id="T_cb99f_row1_col9" class="data row1 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_cb99f_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_cb99f_row2_col0" class="data row2 col0" >ο</td>
#       <td id="T_cb99f_row2_col1" class="data row2 col1" >_____</td>
#       <td id="T_cb99f_row2_col2" class="data row2 col2" >_____</td>
#       <td id="T_cb99f_row2_col3" class="data row2 col3" >_____</td>
#       <td id="T_cb99f_row2_col4" class="data row2 col4" >_____</td>
#       <td id="T_cb99f_row2_col5" class="data row2 col5" >_____</td>
#       <td id="T_cb99f_row2_col6" class="data row2 col6" >_____</td>
#       <td id="T_cb99f_row2_col7" class="data row2 col7" >_____</td>
#       <td id="T_cb99f_row2_col8" class="data row2 col8" >_____</td>
#       <td id="T_cb99f_row2_col9" class="data row2 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_cb99f_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_cb99f_row3_col0" class="data row3 col0" >ο</td>
#       <td id="T_cb99f_row3_col1" class="data row3 col1" >_____</td>
#       <td id="T_cb99f_row3_col2" class="data row3 col2" >_____</td>
#       <td id="T_cb99f_row3_col3" class="data row3 col3" >_____</td>
#       <td id="T_cb99f_row3_col4" class="data row3 col4" >_____</td>
#       <td id="T_cb99f_row3_col5" class="data row3 col5" >_____</td>
#       <td id="T_cb99f_row3_col6" class="data row3 col6" >_____</td>
#       <td id="T_cb99f_row3_col7" class="data row3 col7" >_____</td>
#       <td id="T_cb99f_row3_col8" class="data row3 col8" >_____</td>
#       <td id="T_cb99f_row3_col9" class="data row3 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_cb99f_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_cb99f_row4_col0" class="data row4 col0" >ο</td>
#       <td id="T_cb99f_row4_col1" class="data row4 col1" >_____</td>
#       <td id="T_cb99f_row4_col2" class="data row4 col2" >_____</td>
#       <td id="T_cb99f_row4_col3" class="data row4 col3" >_____</td>
#       <td id="T_cb99f_row4_col4" class="data row4 col4" >_____</td>
#       <td id="T_cb99f_row4_col5" class="data row4 col5" >_____</td>
#       <td id="T_cb99f_row4_col6" class="data row4 col6" >_____</td>
#       <td id="T_cb99f_row4_col7" class="data row4 col7" >_____</td>
#       <td id="T_cb99f_row4_col8" class="data row4 col8" >_____</td>
#       <td id="T_cb99f_row4_col9" class="data row4 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_cb99f_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_cb99f_row5_col0" class="data row5 col0" >START</td>
#       <td id="T_cb99f_row5_col1" class="data row5 col1" >_____</td>
#       <td id="T_cb99f_row5_col2" class="data row5 col2" >_____</td>
#       <td id="T_cb99f_row5_col3" class="data row5 col3" >_____</td>
#       <td id="T_cb99f_row5_col4" class="data row5 col4" >_____</td>
#       <td id="T_cb99f_row5_col5" class="data row5 col5" >_____</td>
#       <td id="T_cb99f_row5_col6" class="data row5 col6" >_____</td>
#       <td id="T_cb99f_row5_col7" class="data row5 col7" >_____</td>
#       <td id="T_cb99f_row5_col8" class="data row5 col8" >_____</td>
#       <td id="T_cb99f_row5_col9" class="data row5 col9" >GOAL</td>
#     </tr>
#   </tbody>
# </table>
# Fringe => [((5, 2), 14), ((4, 2), 15), ((3, 2), 16), ((1, 1), 15), ((2, 2), 13)]
# popped (2, 2) and tracked below
# <style type="text/css">
# #T_a112a_row0_col0, #T_a112a_row0_col1, #T_a112a_row0_col2, #T_a112a_row0_col3, #T_a112a_row0_col4, #T_a112a_row0_col5, #T_a112a_row0_col6, #T_a112a_row0_col7, #T_a112a_row0_col8, #T_a112a_row0_col9, #T_a112a_row1_col0, #T_a112a_row1_col1, #T_a112a_row1_col2, #T_a112a_row1_col3, #T_a112a_row1_col4, #T_a112a_row1_col5, #T_a112a_row1_col6, #T_a112a_row1_col7, #T_a112a_row1_col8, #T_a112a_row1_col9, #T_a112a_row2_col0, #T_a112a_row2_col4, #T_a112a_row2_col8, #T_a112a_row2_col9, #T_a112a_row3_col0, #T_a112a_row3_col4, #T_a112a_row3_col8, #T_a112a_row3_col9, #T_a112a_row4_col0, #T_a112a_row4_col4, #T_a112a_row4_col8, #T_a112a_row4_col9, #T_a112a_row5_col0, #T_a112a_row5_col9 {
#   font-weight: bold;
#   text-align: center;
#   background-color: white;
#   color: black;
# }
# #T_a112a_row2_col1, #T_a112a_row2_col2, #T_a112a_row2_col3, #T_a112a_row2_col5, #T_a112a_row2_col6, #T_a112a_row2_col7, #T_a112a_row3_col1, #T_a112a_row3_col2, #T_a112a_row3_col3, #T_a112a_row3_col5, #T_a112a_row3_col6, #T_a112a_row3_col7, #T_a112a_row4_col1, #T_a112a_row4_col2, #T_a112a_row4_col3, #T_a112a_row4_col5, #T_a112a_row4_col6, #T_a112a_row4_col7 {
#   font-weight: bold;
#   text-align: center;
#   background-color: lightgreen;
#   color: black;
# }
# #T_a112a_row5_col1, #T_a112a_row5_col2, #T_a112a_row5_col3, #T_a112a_row5_col4, #T_a112a_row5_col5, #T_a112a_row5_col6, #T_a112a_row5_col7, #T_a112a_row5_col8 {
#   font-weight: bold;
#   text-align: center;
#   background-color: red;
#   color: black;
# }
# </style>
# <table id="T_a112a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >1</th>
#       <th class="col_heading level0 col1" >2</th>
#       <th class="col_heading level0 col2" >3</th>
#       <th class="col_heading level0 col3" >4</th>
#       <th class="col_heading level0 col4" >5</th>
#       <th class="col_heading level0 col5" >6</th>
#       <th class="col_heading level0 col6" >7</th>
#       <th class="col_heading level0 col7" >8</th>
#       <th class="col_heading level0 col8" >9</th>
#       <th class="col_heading level0 col9" >10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a112a_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a112a_row0_col0" class="data row0 col0" >_____</td>
#       <td id="T_a112a_row0_col1" class="data row0 col1" >_____</td>
#       <td id="T_a112a_row0_col2" class="data row0 col2" >_____</td>
#       <td id="T_a112a_row0_col3" class="data row0 col3" >_____</td>
#       <td id="T_a112a_row0_col4" class="data row0 col4" >_____</td>
#       <td id="T_a112a_row0_col5" class="data row0 col5" >_____</td>
#       <td id="T_a112a_row0_col6" class="data row0 col6" >_____</td>
#       <td id="T_a112a_row0_col7" class="data row0 col7" >_____</td>
#       <td id="T_a112a_row0_col8" class="data row0 col8" >_____</td>
#       <td id="T_a112a_row0_col9" class="data row0 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_a112a_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_a112a_row1_col0" class="data row1 col0" >ο</td>
#       <td id="T_a112a_row1_col1" class="data row1 col1" >ο</td>
#       <td id="T_a112a_row1_col2" class="data row1 col2" >_____</td>
#       <td id="T_a112a_row1_col3" class="data row1 col3" >_____</td>
#       <td id="T_a112a_row1_col4" class="data row1 col4" >_____</td>
#       <td id="T_a112a_row1_col5" class="data row1 col5" >_____</td>
#       <td id="T_a112a_row1_col6" class="data row1 col6" >_____</td>
#       <td id="T_a112a_row1_col7" class="data row1 col7" >_____</td>
#       <td id="T_a112a_row1_col8" class="data row1 col8" >_____</td>
#       <td id="T_a112a_row1_col9" class="data row1 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_a112a_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_a112a_row2_col0" class="data row2 col0" >ο</td>
#       <td id="T_a112a_row2_col1" class="data row2 col1" >_____</td>
#       <td id="T_a112a_row2_col2" class="data row2 col2" >_____</td>
#       <td id="T_a112a_row2_col3" class="data row2 col3" >_____</td>
#       <td id="T_a112a_row2_col4" class="data row2 col4" >_____</td>
#       <td id="T_a112a_row2_col5" class="data row2 col5" >_____</td>
#       <td id="T_a112a_row2_col6" class="data row2 col6" >_____</td>
#       <td id="T_a112a_row2_col7" class="data row2 col7" >_____</td>
#       <td id="T_a112a_row2_col8" class="data row2 col8" >_____</td>
#       <td id="T_a112a_row2_col9" class="data row2 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_a112a_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_a112a_row3_col0" class="data row3 col0" >ο</td>
#       <td id="T_a112a_row3_col1" class="data row3 col1" >_____</td>
#       <td id="T_a112a_row3_col2" class="data row3 col2" >_____</td>
#       <td id="T_a112a_row3_col3" class="data row3 col3" >_____</td>
#       <td id="T_a112a_row3_col4" class="data row3 col4" >_____</td>
#       <td id="T_a112a_row3_col5" class="data row3 col5" >_____</td>
#       <td id="T_a112a_row3_col6" class="data row3 col6" >_____</td>
#       <td id="T_a112a_row3_col7" class="data row3 col7" >_____</td>
#       <td id="T_a112a_row3_col8" class="data row3 col8" >_____</td>
#       <td id="T_a112a_row3_col9" class="data row3 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_a112a_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_a112a_row4_col0" class="data row4 col0" >ο</td>
#       <td id="T_a112a_row4_col1" class="data row4 col1" >_____</td>
#       <td id="T_a112a_row4_col2" class="data row4 col2" >_____</td>
#       <td id="T_a112a_row4_col3" class="data row4 col3" >_____</td>
#       <td id="T_a112a_row4_col4" class="data row4 col4" >_____</td>
#       <td id="T_a112a_row4_col5" class="data row4 col5" >_____</td>
#       <td id="T_a112a_row4_col6" class="data row4 col6" >_____</td>
#       <td id="T_a112a_row4_col7" class="data row4 col7" >_____</td>
#       <td id="T_a112a_row4_col8" class="data row4 col8" >_____</td>
#       <td id="T_a112a_row4_col9" class="data row4 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_a112a_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_a112a_row5_col0" class="data row5 col0" >START</td>
#       <td id="T_a112a_row5_col1" class="data row5 col1" >_____</td>
#       <td id="T_a112a_row5_col2" class="data row5 col2" >_____</td>
#       <td id="T_a112a_row5_col3" class="data row5 col3" >_____</td>
#       <td id="T_a112a_row5_col4" class="data row5 col4" >_____</td>
#       <td id="T_a112a_row5_col5" class="data row5 col5" >_____</td>
#       <td id="T_a112a_row5_col6" class="data row5 col6" >_____</td>
#       <td id="T_a112a_row5_col7" class="data row5 col7" >_____</td>
#       <td id="T_a112a_row5_col8" class="data row5 col8" >_____</td>
# ...
#       <td id="T_e43d4_row3_col8" class="data row3 col8" >ο</td>
#       <td id="T_e43d4_row3_col9" class="data row3 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_e43d4_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_e43d4_row4_col0" class="data row4 col0" >ο</td>
#       <td id="T_e43d4_row4_col1" class="data row4 col1" >_____</td>
#       <td id="T_e43d4_row4_col2" class="data row4 col2" >_____</td>
#       <td id="T_e43d4_row4_col3" class="data row4 col3" >_____</td>
#       <td id="T_e43d4_row4_col4" class="data row4 col4" >ο</td>
#       <td id="T_e43d4_row4_col5" class="data row4 col5" >_____</td>
#       <td id="T_e43d4_row4_col6" class="data row4 col6" >_____</td>
#       <td id="T_e43d4_row4_col7" class="data row4 col7" >_____</td>
#       <td id="T_e43d4_row4_col8" class="data row4 col8" >ο</td>
#       <td id="T_e43d4_row4_col9" class="data row4 col9" >ο</td>
#     </tr>
#     <tr>
#       <th id="T_e43d4_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_e43d4_row5_col0" class="data row5 col0" >START</td>
#       <td id="T_e43d4_row5_col1" class="data row5 col1" >_____</td>
#       <td id="T_e43d4_row5_col2" class="data row5 col2" >_____</td>
#       <td id="T_e43d4_row5_col3" class="data row5 col3" >_____</td>
#       <td id="T_e43d4_row5_col4" class="data row5 col4" >_____</td>
#       <td id="T_e43d4_row5_col5" class="data row5 col5" >_____</td>
#       <td id="T_e43d4_row5_col6" class="data row5 col6" >_____</td>
#       <td id="T_e43d4_row5_col7" class="data row5 col7" >_____</td>
#       <td id="T_e43d4_row5_col8" class="data row5 col8" >_____</td>
#       <td id="T_e43d4_row5_col9" class="data row5 col9" >GOAL</td>
#     </tr>
#   </tbody>
# </table>
# Fringe => [((5, 2), 14), ((4, 2), 15), ((1, 1), 15), ((1, 2), 14), ((3, 2), 16), ((1, 3), 13), ((3, 3), 15), ((1, 4), 12), ((1, 5), 11), ((3, 4), 14), ((4, 4), 13), ((4, 6), 11), ((5, 4), 12), ((5, 6), 10), ((1, 6), 10), ((3, 6), 12), ((1, 7), 9), ((3, 7), 11), ((1, 8), 8), ((1, 9), 7), ((2, 10), 5), ((3, 8), 10), ((3, 10), 4), ((4, 8), 9), ((5, 8), 8), ((4, 10), 3), ((6, 10), 1)]
# popped (6, 10) and tracked below
# <style type="text/css">
# #T_9ecd2_row0_col0, #T_9ecd2_row0_col1, #T_9ecd2_row0_col2, #T_9ecd2_row0_col3, #T_9ecd2_row0_col4, #T_9ecd2_row0_col5, #T_9ecd2_row0_col6, #T_9ecd2_row0_col7, #T_9ecd2_row0_col8, #T_9ecd2_row0_col9, #T_9ecd2_row1_col0, #T_9ecd2_row1_col1, #T_9ecd2_row1_col2, #T_9ecd2_row1_col3, #T_9ecd2_row1_col4, #T_9ecd2_row1_col5, #T_9ecd2_row1_col6, #T_9ecd2_row1_col7, #T_9ecd2_row1_col8, #T_9ecd2_row1_col9, #T_9ecd2_row2_col0, #T_9ecd2_row2_col4, #T_9ecd2_row2_col8, #T_9ecd2_row2_col9, #T_9ecd2_row3_col0, #T_9ecd2_row3_col4, #T_9ecd2_row3_col8, #T_9ecd2_row3_col9, #T_9ecd2_row4_col0, #T_9ecd2_row4_col4, #T_9ecd2_row4_col8, #T_9ecd2_row4_col9, #T_9ecd2_row5_col0, #T_9ecd2_row5_col9 {
#   font-weight: bold;
#   text-align: center;
#   background-color: white;
#   color: black;
# }
# #T
_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_9ecd2_row5_col0" class="data row5 col0" >START</td>
#       <td id="T_9ecd2_row5_col1" class="data row5 col1" >_____</td>
#       <td id="T_9ecd2_row5_col2" class="data row5 col2" >_____</td>
#       <td id="T_9ecd2_row5_col3" class="data row5 col3" >_____</td>
#       <td id="T_9ecd2_row5_col4" class="data row5 col4" >_____</td>
#       <td id="T_9ecd2_row5_col5" class="data row5 col5" >_____</td>
#       <td id="T_9ecd2_row5_col6" class="data row5 col6" >_____</td>
#       <td id="T_9ecd2_row5_col7" class="data row5 col7" >_____</td>
#       <td id="T_9ecd2_row5_col8" class="data row5 col8" >_____</td>
#       <td id="T_9ecd2_row5_col9" class="data row5 col9" >GOAL</td>
#     </tr>
#   </tbody>
# </table>
# A* found GOAL
# A* path backtracked START to GOAL =>[(6, 1), (5, 1), (4, 1), (3, 1), (2, 1), (2, 2), (2, 3), (2, 4), (2, 5), (2, 6), (2, 7), (2, 8), (2, 9), (3, 9), (4, 9), (5, 9), (5, 10), (6, 10)]
# A* Path Cost = 18
#
# Output of explored areas with output cost at each step higlighted in blue color:
# <style type="text/css">
# #T_c8b26_row0_col0, #T_c8b26_row0_col1, #T_c8b26_row0_col2, #T_c8b26_row0_col3, #T_c8b26_row0_col4, #T_c8b26_row0_col5, #T_c8b26_row0_col6, #T_c8b26_row0_col7, #T_c8b26_row0_col8, #T_c8b26_row0_col9, #T_c8b26_row1_col9, #T_c8b26_row2_col4, #T_c8b26_row2_col9, #T_c8b26_row3_col4, #T_c8b26_row3_col9, #T_c8b26_row4_col4 {
#   font-weight: bold;
#   text-align: center;
#   background-color: white;
#   color: black;
# }
# #T_c8b26_row1_col0, #T_c8b26_row1_col1, #T_c8b26_row1_col2, #T_c8b26_row1_col3, #T_c8b26_row1_col4, #T_c8b26_row1_col5, #T_c8b26_row1_col6, #T_c8b26_row1_col7, #T_c8b26_row1_col8, #T_c8b26_row2_col0, #T_c8b26_row2_col8, #T_c8b26_row3_col0, #T_c8b26_row3_col8, #T_c8b26_row4_col0, #T_c8b26_row4_col8, #T_c8b26_row4_col9, #T_c8b26_row5_col0, #T_c8b26_row5_col9 {
#   font-weight: bold;
#   text-align: center;
#   background-color: white;
#   color: blue;
# }
# #T_c8b26_row2_col1, #T_c8b26_row2_col2, #T_c8b26_row2_col3, #T_c8b26_row2_col5, #T_c8b26_row2_col6, #T_c8b26_row2_col7, #T_c8b26_row3_col1, #T_c8b26_row3_col2, #T_c8b26_row3_col3, #T_c8b26_row3_col5, #T_c8b26_row3_col6, #T_c8b26_row3_col7, #T_c8b26_row4_col1, #T_c8b26_row4_col2, #T_c8b26_row4_col3, #T_c8b26_row4_col5, #T_c8b26_row4_col6, #T_c8b26_row4_col7 {
#   font-weight: bold;
#   text-align: center;
#   background-color: lightgreen;
#   color: black;
# }
# #T_c8b26_row5_col1, #T_c8b26_row5_col2, #T_c8b26_row5_col3, #T_c8b26_row5_col4, #T_c8b26_row5_col5, #T_c8b26_row5_col6, #T_c8b26_row5_col7, #T_c8b26_row5_col8 {
#   font-weight: bold;
#   text-align: center;
#   background-color: red;
#   color: black;
# }
# </style>
# <table id="T_c8b26_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >1</th>
#       <th class="col_heading level0 col1" >2</th>
#       <th class="col_heading level0 col2" >3</th>
#       <th class="col_heading level0 col3" >4</th>
#       <th class="col_heading level0 col4" >5</th>
#       <th class="col_heading level0 col5" >6</th>
#       <th class="col_heading level0 col6" >7</th>
#       <th class="col_heading level0 col7" >8</th>
#       <th class="col_heading level0 col8" >9</th>
#       <th class="col_heading level0 col9" >10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8b26_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_c8b26_row0_col0" class="data row0 col0" >_____</td>
#       <td id="T_c8b26_row0_col1" class="data row0 col1" >_____</td>
#       <td id="T_c8b26_row0_col2" class="data row0 col2" >_____</td>
#       <td id="T_c8b26_row0_col3" class="data row0 col3" >_____</td>
#       <td id="T_c8b26_row0_col4" class="data row0 col4" >_____</td>
#       <td id="T_c8b26_row0_col5" class="data row0 col5" >_____</td>
#       <td id="T_c8b26_row0_col6" class="data row0 col6" >_____</td>
#       <td id="T_c8b26_row0_col7" class="data row0 col7" >_____</td>
#       <td id="T_c8b26_row0_col8" class="data row0 col8" >_____</td>
#       <td id="T_c8b26_row0_col9" class="data row0 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_c8b26_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_c8b26_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_c8b26_row1_col1" class="data row1 col1" >6</td>
#       <td id="T_c8b26_row1_col2" class="data row1 col2" >7</td>
#       <td id="T_c8b26_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_c8b26_row1_col4" class="data row1 col4" >9</td>
#       <td id="T_c8b26_row1_col5" class="data row1 col5" >10</td>
#       <td id="T_c8b26_row1_col6" class="data row1 col6" >11</td>
#       <td id="T_c8b26_row1_col7" class="data row1 col7" >12</td>
#       <td id="T_c8b26_row1_col8" class="data row1 col8" >13</td>
#       <td id="T_c8b26_row1_col9" class="data row1 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_c8b26_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_c8b26_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_c8b26_row2_col1" class="data row2 col1" >_____</td>
#       <td id="T_c8b26_row2_col2" class="data row2 col2" >_____</td>
#       <td id="T_c8b26_row2_col3" class="data row2 col3" >_____</td>
#       <td id="T_c8b26_row2_col4" class="data row2 col4" >ο</td>
#       <td id="T_c8b26_row2_col5" class="data row2 col5" >_____</td>
#       <td id="T_c8b26_row2_col6" class="data row2 col6" >_____</td>
#       <td id="T_c8b26_row2_col7" class="data row2 col7" >_____</td>
#       <td id="T_c8b26_row2_col8" class="data row2 col8" >14</td>
#       <td id="T_c8b26_row2_col9" class="data row2 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_c8b26_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_c8b26_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_c8b26_row3_col1" class="data row3 col1" >_____</td>
#       <td id="T_c8b26_row3_col2" class="data row3 col2" >_____</td>
#       <td id="T_c8b26_row3_col3" class="data row3 col3" >_____</td>
#       <td id="T_c8b26_row3_col4" class="data row3 col4" >ο</td>
#       <td id="T_c8b26_row3_col5" class="data row3 col5" >_____</td>
#       <td id="T_c8b26_row3_col6" class="data row3 col6" >_____</td>
#       <td id="T_c8b26_row3_col7" class="data row3 col7" >_____</td>
#       <td id="T_c8b26_row3_col8" class="data row3 col8" >15</td>
#       <td id="T_c8b26_row3_col9" class="data row3 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_c8b26_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_c8b26_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_c8b26_row4_col1" class="data row4 col1" >_____</td>
#       <td id="T_c8b26_row4_col2" class="data row4 col2" >_____</td>
#       <td id="T_c8b26_row4_col3" class="data row4 col3" >_____</td>
#       <td id="T_c8b26_row4_col4" class="data row4 col4" >ο</td>
#       <td id="T_c8b26_row4_col5" class="data row4 col5" >_____</td>
#       <td id="T_c8b26_row4_col6" class="data row4 col6" >_____</td>
#       <td id="T_c8b26_row4_col7" class="data row4 col7" >_____</td>
#       <td id="T_c8b26_row4_col8" class="data row4 col8" >16</td>
#       <td id="T_c8b26_row4_col9" class="data row4 col9" >17</td>
#     </tr>
#     <tr>
#       <th id="T_c8b26_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_c8b26_row5_col0" class="data row5 col0" >START=1</td>
#       <td id="T_c8b26_row5_col1" class="data row5 col1" >_____</td>
#       <td id="T_c8b26_row5_col2" class="data row5 col2" >_____</td>
#       <td id="T_c8b26_row5_col3" class="data row5 col3" >_____</td>
#       <td id="T_c8b26_row5_col4" class="data row5 col4" >_____</td>
#       <td id="T_c8b26_row5_col5" class="data row5 col5" >_____</td>
#       <td id="T_c8b26_row5_col6" class="data row5 col6" >_____</td>
#       <td id="T_c8b26_row5_col7" class="data row5 col7" >_____</td>
#       <td id="T_c8b26_row5_col8" class="data row5 col8" >_____</td>
#       <td id="T_c8b26_row5_col9" class="data row5 col9" >GOAL=18</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Final answer of A* below**

# %%
print("A* path backtracked START to GOAL =>"+str(path_a_star))
print("A* Path Cost = "+str(a_star_path_cost))
print()
print("Output of explored areas with output cost at each step higlighted in blue color:")
display(print_cliff_walker())
# Out:
# A* path backtracked START to GOAL =>[(6, 1), (5, 1), (4, 1), (3, 1), (2, 1), (2, 2), (2, 3), (2, 4), (2, 5), (2, 6), (2, 7), (2, 8), (2, 9), (3, 9), (4, 9), (5, 9), (5, 10), (6, 10)]
# A* Path Cost = 18
#
# Output of explored areas with output cost at each step higlighted in blue color:
# <style type="text/css">
# #T_79b22_row0_col0, #T_79b22_row0_col1, #T_79b22_row0_col2, #T_79b22_row0_col3, #T_79b22_row0_col4, #T_79b22_row0_col5, #T_79b22_row0_col6, #T_79b22_row0_col7, #T_79b22_row0_col8, #T_79b22_row0_col9, #T_79b22_row1_col9, #T_79b22_row2_col4, #T_79b22_row2_col9, #T_79b22_row3_col4, #T_79b22_row3_col9, #T_79b22_row4_col4 {
#   font-weight: bold;
#   text-align: center;
#   background-color: white;
#   color: black;
# }
# #T_79b22_row1_col0, #T_79b22_row1_col1, #T_79b22_row1_col2, #T_79b22_row1_col3, #T_79b22_row1_col4, #T_79b22_row1_col5, #T_79b22_row1_col6, #T_79b22_row1_col7, #T_79b22_row1_col8, #T_79b22_row2_col0, #T_79b22_row2_col8, #T_79b22_row3_col0, #T_79b22_row3_col8, #T_79b22_row4_col0, #T_79b22_row4_col8, #T_79b22_row4_col9, #T_79b22_row5_col0, #T_79b22_row5_col9 {
#   font-weight: bold;
#   text-align: center;
#   background-color: white;
#   color: blue;
# }
# #T_79b22_row2_col1, #T_79b22_row2_col2, #T_79b22_row2_col3, #T_79b22_row2_col5, #T_79b22_row2_col6, #T_79b22_row2_col7, #T_79b22_row3_col1, #T_79b22_row3_col2, #T_79b22_row3_col3, #T_79b22_row3_col5, #T_79b22_row3_col6, #T_79b22_row3_col7, #T_79b22_row4_col1, #T_79b22_row4_col2, #T_79b22_row4_col3, #T_79b22_row4_col5, #T_79b22_row4_col6, #T_79b22_row4_col7 {
#   font-weight: bold;
#   text-align: center;
#   background-color: lightgreen;
#   color: black;
# }
# #T_79b22_row5_col1, #T_79b22_row5_col2, #T_79b22_row5_col3, #T_79b22_row5_col4, #T_79b22_row5_col5, #T_79b22_row5_col6, #T_79b22_row5_col7, #T_79b22_row5_col8 {
#   font-weight: bold;
#   text-align: center;
#   background-color: red;
#   color: black;
# }
# </style>
# <table id="T_79b22_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >1</th>
#       <th class="col_heading level0 col1" >2</th>
#       <th class="col_heading level0 col2" >3</th>
#       <th class="col_heading level0 col3" >4</th>
#       <th class="col_heading level0 col4" >5</th>
#       <th class="col_heading level0 col5" >6</th>
#       <th class="col_heading level0 col6" >7</th>
#       <th class="col_heading level0 col7" >8</th>
#       <th class="col_heading level0 col8" >9</th>
#       <th class="col_heading level0 col9" >10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79b22_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_79b22_row0_col0" class="data row0 col0" >_____</td>
#       <td id="T_79b22_row0_col1" class="data row0 col1" >_____</td>
#       <td id="T_79b22_row0_col2" class="data row0 col2" >_____</td>
#       <td id="T_79b22_row0_col3" class="data row0 col3" >_____</td>
#       <td id="T_79b22_row0_col4" class="data row0 col4" >_____</td>
#       <td id="T_79b22_row0_col5" class="data row0 col5" >_____</td>
#       <td id="T_79b22_row0_col6" class="data row0 col6" >_____</td>
#       <td id="T_79b22_row0_col7" class="data row0 col7" >_____</td>
#       <td id="T_79b22_row0_col8" class="data row0 col8" >_____</td>
#       <td id="T_79b22_row0_col9" class="data row0 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_79b22_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_79b22_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_79b22_row1_col1" class="data row1 col1" >6</td>
#       <td id="T_79b22_row1_col2" class="data row1 col2" >7</td>
#       <td id="T_79b22_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_79b22_row1_col4" class="data row1 col4" >9</td>
#       <td id="T_79b22_row1_col5" class="data row1 col5" >10</td>
#       <td id="T_79b22_row1_col6" class="data row1 col6" >11</td>
#       <td id="T_79b22_row1_col7" class="data row1 col7" >12</td>
#       <td id="T_79b22_row1_col8" class="data row1 col8" >13</td>
#       <td id="T_79b22_row1_col9" class="data row1 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_79b22_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_79b22_row2_col0" class="data row2 col0" >4</td>
#       <td id="T_79b22_row2_col1" class="data row2 col1" >_____</td>
#       <td id="T_79b22_row2_col2" class="data row2 col2" >_____</td>
#       <td id="T_79b22_row2_col3" class="data row2 col3" >_____</td>
#       <td id="T_79b22_row2_col4" class="data row2 col4" >ο</td>
#       <td id="T_79b22_row2_col5" class="data row2 col5" >_____</td>
#       <td id="T_79b22_row2_col6" class="data row2 col6" >_____</td>
#       <td id="T_79b22_row2_col7" class="data row2 col7" >_____</td>
#       <td id="T_79b22_row2_col8" class="data row2 col8" >14</td>
#       <td id="T_79b22_row2_col9" class="data row2 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_79b22_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_79b22_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_79b22_row3_col1" class="data row3 col1" >_____</td>
#       <td id="T_79b22_row3_col2" class="data row3 col2" >_____</td>
#       <td id="T_79b22_row3_col3" class="data row3 col3" >_____</td>
#       <td id="T_79b22_row3_col4" class="data row3 col4" >ο</td>
#       <td id="T_79b22_row3_col5" class="data row3 col5" >_____</td>
#       <td id="T_79b22_row3_col6" class="data row3 col6" >_____</td>
#       <td id="T_79b22_row3_col7" class="data row3 col7" >_____</td>
#       <td id="T_79b22_row3_col8" class="data row3 col8" >15</td>
#       <td id="T_79b22_row3_col9" class="data row3 col9" >_____</td>
#     </tr>
#     <tr>
#       <th id="T_79b22_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_79b22_row4_col0" class="data row4 col0" >2</td>
#       <td id="T_79b22_row4_col1" class="data row4 col1" >_____</td>
#       <td id="T_79b22_row4_col2" class="data row4 col2" >_____</td>
#       <td id="T_79b22_row4_col3" class="data row4 col3" >_____</td>
#       <td id="T_79b22_row4_col4" class="data row4 col4" >ο</td>
#       <td id="T_79b22_row4_col5" class="data row4 col5" >_____</td>
#       <td id="T_79b22_row4_col6" class="data row4 col6" >_____</td>
#       <td id="T_79b22_row4_col7" class="data row4 col7" >_____</td>
#       <td id="T_79b22_row4_col8" class="data row4 col8" >16</td>
#       <td id="T_79b22_row4_col9" class="data row4 col9" >17</td>
#     </tr>
#     <tr>
#       <th id="T_79b22_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_79b22_row5_col0" class="data row5 col0" >START=1</td>
#       <td id="T_79b22_row5_col1" class="data row5 col1" >_____</td>
#       <td id="T_79b22_row5_col2" class="data row5 col2" >_____</td>
#       <td id="T_79b22_row5_col3" class="data row5 col3" >_____</td>
#       <td id="T_79b22_row5_col4" class="data row5 col4" >_____</td>
#       <td id="T_79b22_row5_col5" class="data row5 col5" >_____</td>
#       <td id="T_79b22_row5_col6" class="data row5 col6" >_____</td>
#       <td id="T_79b22_row5_col7" class="data row5 col7" >_____</td>
#       <td id="T_79b22_row5_col8" class="data row5 col8" >_____</td>
#       <td id="T_79b22_row5_col9" class="data row5 col9" >GOAL=18</td>
#     </tr>
#   </tbody>
# </table>
